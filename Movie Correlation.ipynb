# %% [markdown]
# This project is made to assess and derive the degree, and direction of the relationship between the gross earnings of movies and other variables

# %%
#import libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)

# %%
movie = pd.read_csv('movies.csv')
movie.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#checking missing data

for col in movie.columns:
    pct_missing = np.mean(movie[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#replacing missing values in the budget column with the mean value of the column
mean_value = movie['budget'].mean()
movie['budget'].fillna(value=mean_value, inplace=True)

# %%
#replacing the missing values in the gross column with the mean value of the column
mean_v = movie['gross'].mean()
movie['gross'].fillna(value=mean_v, inplace=True)

# %%
movie['gross'] = movie['gross'].abs()

# %%
movie.dtypes
# Out:
# name          int16
# rating         int8
# genre          int8
# year          int64
# released      int16
# score       float64
# votes       float64
# director      int16
# writer        int16
# star          int16
# country        int8
# budget      float64
# gross       float64
# company       int16
# runtime     float64
# dtype: object

# %%
#turning the budget and gross to integer

movie = movie.astype({"budget":"int64","gross":"int64"})

# %%
movie.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
movie.sort_values(by=['gross'], inplace=False, ascending=False).head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0

# %%
#Drop any duplicates

movie['company'].drop_duplicates().sort_values(ascending=False).head()
# Out:
# 7129    2384
# 5664    2383
# 6412    2382
# 4007    2381
# 6793    2380
# Name: company, dtype: int16

# %%
#scatter plot with budget vs gross

plt.scatter(x=movie['budget'], y=movie['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget')
plt.show()

# %%
#plot budget vs gross using seaborn
sns.regplot(x='budget', y='gross', data=movie, scatter_kws={"color":"black"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#correlation
movie.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.265578  0.254971  0.120811
# score    0.097995  1.000000  0.409182  0.064554  0.183956  0.399451
# votes    0.222945  0.409182  1.000000  0.421090  0.632852  0.309212
# budget   0.265578  0.064554  0.421090  1.000000  0.714942  0.265305
# gross    0.254971  0.183956  0.632852  0.714942  1.000000  0.241421
# runtime  0.120811  0.399451  0.309212  0.265305  0.241421  1.000000

# %%
correlation_matrix = movie.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
##looking at company
movie_numerized = movie

for col_name in movie_numerized.columns:
    if(movie_numerized[col_name].dtype == 'object'):
        movie_numerized[col_name]=movie_numerized[col_name].astype('category')
        movie_numerized[col_name]=movie_numerized[col_name].cat.codes
        
movie_numerized.head(10)
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
# 5  2109       6     10  1980      2502    6.4   123000.0      2528    4362
# 6  5574       6      0  1980      1771    7.9   188000.0      1412     838
# 7  4436       6      3  1980       699    8.2   330000.0      1829    1769
# 8  5281       4      0  1980      1753    6.8   101000.0      2306    1979
# 9  6213       6      3  1980      2286    7.0    10000.0      2864     423
#
#    star  country      budget        gross  company  runtime
# 0  1047       54  19000000.0   46998772.0     2319    146.0
# ...

# %%
correlation_matrix = movie_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
movie_numerized.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating       -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre         0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year          0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released     -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score         0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes         0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director      0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer        0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star          0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country      -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget        0.020368 -0.126046 -0.310566  0.265578  0.012263  0.064554
# ...

# %%
correlation_mat = movie_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.011311
#               score           0.017097
#               votes           0.013088
#               director        0.009079
#               writer          0.009081
#               star            0.006472
#               country        -0.010737
#               budget          0.020368
#               gross           0.007123
#               company         0.009211
#               runtime         0.010392
#               year_correct   -0.011725
# rating        name           -0.008069
#               rating          1.000000
#               genre           0.072423
#               year            0.008779
#               released        0.016613
#               score          -0.001314
#               votes           0.033225
#               director        0.019483
# ...

# %%
high_corr = corr_pairs[(corr_pairs) > 0.5]

high_corr
# Out:
# name          name            1.000000
# rating        rating          1.000000
# genre         genre           1.000000
# year          year            1.000000
# released      released        1.000000
#               year_correct    0.993694
# score         score           1.000000
# votes         votes           1.000000
#               gross           0.632852
# director      director        1.000000
# writer        writer          1.000000
# star          star            1.000000
# country       country         1.000000
# budget        budget          1.000000
#               gross           0.714942
# gross         votes           0.632852
#               budget          0.714942
#               gross           1.000000
# company       company         1.000000
# runtime       runtime         1.000000
# year_correct  released        0.993694
#               year_correct    1.000000
# dtype: float64

# %% [markdown]
# Votes and the movie budgets have the highest correlation to the gross earnings of the movies
#
# The movie production companies have low correlation to the gross earnings
